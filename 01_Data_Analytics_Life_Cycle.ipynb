# %% [markdown]
# ### Data Analytics Life Cycle

# %%
# Step 1:-                    Objective (What, Why, How to do?)
#                                          ||
# Step 2:-              Understanding Data (Observing data carefully)
#                                          ||
# Step 3:-       Data Cleaning and Data transformation (Remove null values, etc)
#                                          ||
# Step 4:-            Data Enhancement (Final Data after data cleaning)
#                                          ||
# Step 5:-        Data Analytics (Plotting Graphs and charts based on analysis)
#                                          ||
# Step 6:-      Data Visualization (Visualizing Data with the help of Power BI)
